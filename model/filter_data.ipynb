# %%
import os
import pandas as pd
from sklearn import tree

# %%
df: pd.DataFrame = pd.read_csv(r"data\raw data\caesar.csv")

# %%
df
# Out:
#       index  Unnamed: 0   age  num_children  gender  reported_height  \
# 0         0         NaN   NaN           NaN     NaN              NaN
# 1         1         1.0  47.0           0.0    male             74.0
# 2         2        10.0  50.0           0.0    male             72.0
# 3         3       100.0  28.0           0.0    male             73.0
# 4         4       103.0  52.0           2.0    male             75.0
# ...     ...         ...   ...           ...     ...              ...
# 4460   4460        95.0  35.0           0.0  female             59.5
# 4461   4461        96.0  40.0           1.0  female             66.0
# 4462   4462        97.0  23.0           0.0  female             67.5
# 4463   4463        98.0  24.0           0.0    male             68.0
# 4464   4464        99.0  22.0           0.0  female             68.0
#
#       reported_weight  reported_pants_size_waist  reported_pants_size_inseam  \
# ...
